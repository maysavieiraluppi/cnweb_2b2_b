# %% [markdown]
# <a href="https://colab.research.google.com/github/maysavieiraluppi/cnweb_2b2_b/blob/main/cinematica0409.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formula da Velocidade Média

# %%
def calcVelMedia(deltaS, deltaT):
  velMedia = (deltaS / deltaT)
  return velMedia

# %% [markdown]
# teste de serviço: velocidade media

# %%
print('Velocidade Média: ',calcVelMedia(50, 4))
# Out:
# Velocidade Média:  12.5

# %% [markdown]
# # Fórmula da aceleração

# %%
def calcVelMedia(Velocidade, tempo):

# %% [markdown]
# # Fórmulas do Movimento Uniforme (MU)

# %% [markdown]
# ## Função horária do deslocamento

# %%
 def calcdescolocamento(velocidade,  tempo):
  deslocamento = velocidade * tempo
  return deslocamento

# %%
print( "Fusao horaria:",  calcdeslocamento(15, 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_511/2263450050.py in <cell line: 0>()
# ----> 1 print( "Fusao horaia:", calcdescolocamento(15,  2))
#
# NameError: name 'calcdescolocamento' is not defined

# %% [markdown]
# # Fórmulas do Movimento Uniformemente Variado (MUV)

# %% [markdown]
# ## Função horária da posição

# %% [markdown]
# ## Equação de Torricelli

# %%
import math

def calcTorricelli( vZero, acel,  desloc):
   t = 2 *  acel * desloc
vFinal = t +  Zero
res = roud( math,sqrt(vFinal),  2)
return res

# %%
print("equaçao de torrcelli:",round(calcVelocidadeTorrcelli(15, 4, 3, 5), 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_511/1258571153.py in <cell line: 0>()
# ----> 1 print("equaçao de torrcelli:",round(calcVelocidadeTorrcelli(15, 4, 3, 5), 2))
#
# NameError: name 'calcVelocidadeTorrcelli' is not defined

# %% [markdown]
# # Fórmula do movimento vertical

# %% [markdown]
# ## Equação de Torricelli para lançamento vertical

# %% [markdown]
# ## Velocidade vertical em função do tempo

# %% [markdown]
# ## Posição vertical em função do tempo
