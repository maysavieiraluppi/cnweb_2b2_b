# %% [markdown]
# <a href="https://colab.research.google.com/github/maysavieiraluppi/cnweb_2b2_b/blob/main/cinematica0409.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formula da Velocidade Média

# %%
def calculaVelMedia(deltaS, deltaT):
  velMedia = (deltaS / deltaT)
  return velMedia
print("vm =", calculaVelMedia(30,15))
# Out:
# vm = 2.0

# %% [markdown]
# teste de serviço: velocidade media

# %% [markdown]
# # Fórmula da aceleração

# %%
def calcularVelMedia(Velocidade, Tempo):
  velMedia = (Velocidade / tempo)
  return velMedia
print("Aceleração =", calculaVelMedia(15,2))
# Out:
# Aceleração = 7.5

# %% [markdown]
# # Fórmulas do Movimento Uniforme (MU)

# %%
def calcularPosicaoMU(posicao_inicial, velocidade, tempo):
  posicao_final = posicao_inicial + (velocidade * tempo)
  return posicao_final
print("Movimento uniforme ", calcularPosicaoMU(15, 2, 5))
# Out:
# Movimento uniforme  25

# %% [markdown]
# ## Função horária do deslocamento

# %%
def calcularDeslocamento(velocidade, tempo):
  deslocamento = velocidade * tempo
  return deslocamento
print("Função horária ", calcularDeslocamento(15, 2))
# Out:
# Função horária  30

# %% [markdown]
# # Fórmulas do Movimento Uniformemente Variado (MUV)

# %%
def calcularVelocidadeMUV(velocidade_inicial, aceleracao, tempo):

  velocidade_final = velocidade_inicial + (aceleracao * tempo)
  return velocidade_final
print("Movimento Variado ", calcularVelocidadeMUV(15, 2,2))
# Out:
# Movimento Variado  19

# %% [markdown]
# ## Função horária da posição

# %%
def calcularPosicaoMUV(posicao_inicial, velocidade_inicial, aceleracao, tempo):
  posicao_final = posicao_inicial + (velocidade_inicial * tempo) + (0.5 * aceleracao * (tempo ** 2))
  return posicao_final
print("Função horária da posição:", calcularPosicaoMUV(15,4,3,5))
# Out:
# Função horária da posição: 72.5

# %% [markdown]
# ## Equação de Torricelli

# %%
def calcularPosicaoMUV(posicao_inicial, velocidade_inicial, aceleracao, tempo):
  posicao_final = posicao_inicial + (velocidade_inicial * tempo) + (0.5 * aceleracao * (tempo ** 2))
  return posicao_final
print("Função horária da posição:", calcularPosicaoMUV(15,4,3,5))
# Out:
# Função horária da posição: 72.5

# %% [markdown]
# # Fórmula do movimento vertical

# %%
def posicao_vertical(t, v0=0, h0=0, g=9.8):
    h = h0 + (v0 * t) + (0.5 * g * (t**2))
    return h
print(f"Altura percorrida: {posicao_vertical(t=3)} metros")
# Out:
# Altura percorrida: 44.1 metros

# %% [markdown]
# ## Equação de Torricelli para lançamento vertical

# %%
def calcToricelliVer(vZero, grav, alt):
  vFinal1 = (vZero ** 2)- (2 * grav * alt)
  vFinal2 = (vZero ** 2) + (2 * grav * alt)
  return vFinal1, vFinal2

# %%
print("Torricelli Vertical [Subindo], [Descendo]" ,calcTorricelliVer(50, 10, 100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_494/1181723001.py in <cell line: 0>()
# ----> 1 print ("Torricelli Vertical [Subindo], [Descendo]" ,calcTorricelliVer(50, 10, 100))
#
# NameError: name 'calcTorricelliVer' is not defined

# %% [markdown]
# ## Velocidade vertical em função do tempo

# %%
def velocidade_vertical(t, v0=0, g=9.8):

    v = v0 + (g * t)
    return v

v_inst = velocidade_vertical(t=2)
print(f"A velocidade no instante t=2s é {v_inst:.2f} m/s")

# %% [markdown]
# ## Posição vertical em função do tempo

# %%
def posicao_vertical(t, h0=0, v0=0, g=9.8):

    h = h0 + (v0 * t) + (0.5 * g * (t**2))
    return h

altura = posicao_vertical(t=3)
print(f"A posição vertical após 3s é {altura:.2f} metros")
